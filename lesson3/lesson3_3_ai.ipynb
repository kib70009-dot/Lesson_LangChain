# %%
import requests

def chat_with_ollama(prompt: str):
    url = "http://localhost:11434/api/generate"
    payload = {
        "model": "gemma3:1b",
        "prompt": prompt,
        "stream": False,
        "options": { #參考說明1
            "temperature": 0.7,
            "top_p": 0.9,
            "top_k": 50,
        },
        "max_tokens": 100,
        "format": "json",
    }

    response = requests.post(url, json=payload)
    result = response.json()
    print("💬 AI 回應：")
    # Print the whole result for debugging
    print(result)
    # Try to print the 'response' key if it exists, otherwise print possible keys
    if "response" in result:
        print(result["response"])
    elif "message" in result:
        print(result["message"])
    elif "content" in result:
        print(result["content"])
    else:
        print("No expected key found in response. Available keys:", result.keys())

#範例輸入
chat_with_ollama("請用簡單的方式解釋什麼是Python的函式？")
# Out:
# 💬 AI 回應：
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T08:02:24.0052811Z', 'response': '{\n"解釋：":[\n"Python的函式就像是程式碼的指令，它們可以做各種事情。就像你教一個孩子做事情，函式就是給他們教的步驟。"\n],\n"簡單來說：":[\n"函式是程式碼的組件，它們會執行特定的任務。 你可以把函式看作是程式碼的「步驟」，它們會根據你給的指示來做事情。 就像玩遊戲一樣，你給了指令，程式碼執行了那條路徑，就完成了遊戲。"\n],\n"例子：":[\n"假設你想要計算一個數字，你可以寫一個函式：`def add(x, y):`  這表示，這個函式叫做 `add`，它接受兩個數字 `x` 和 `y` 作為參數，然後計算 `x + y`，再輸出結果。 這樣，你就可以用這個函式來計算加法。"\n],\n"重點：":[\n"函式必須有一個名稱，並且可以接受一些參數（輸入），並輸出一個結果。  它們也可以有返回值（輸出），讓程式後續使用時可以得到結果。"\n]\n}', 'done': True, 'done_reason': 'stop', 'context': [105, 2364, 107, 239230, 237105, 74624, 48280, 185411, 26549, 237026, 32651, 236918, 238780, 237522, 237536, 106, 107, 105, 4368, 107, 236782, 107, 236775, 185411, 237184, 89045, 107, 236775, 32651, 236918, 238780, 237522, 55326, 237026, 47972, 240897, 236918, 81582, 236900, 162576, 5157, 237893, 77722, 25606, 236924, 55326, 237408, 237885, 19966, 24017, 237893, 25606, 236900, 238780, 237522, 7888, 238966, 41315, 237885, 236918, 167951, 165220, 107, 1604, 107, 236775, 74624, 94757, 237184, 89045, 107, 236775, 238780, 237522, 237026, 47972, 240897, 236918, 238578, 237523, 236900, 162576, 238003, 78204, 172612, 152807, 236924, 43758, 5157, 238061, 238780, 237522, 237506, 237284, 237026, 47972, 240897, 236918, 237374, 167951, 48311, 162576, 238003, 99647, 237408, 238966, 236918, 96180, 237967, 237893, 25606, 236924, 236743, 55326, 238681, 49704, 59246, 236900, 237408, 238966, 237089, 81582, 236900, 47972, 240897, 78204, 237089, 237581, 240164, 237844, 242495, 236900, 237278, 136419, 49704, 165220, 107, 1604, 107, 236775, 69954, 237184, 89045, 107, 236775, 206402, 237408, 34860, 44068, 19966, 210921, 236900, 71407, 240564, 19966, 238780, 237522, 237184, 236929, 2063, 1138, 236769, 236781, 236764, 570, 1473, 236929, 138, 237745, 14237, 236900, 17161, 238780, 237522, 100083, 2165, 1282, 236929, 236900, 238010, 38313, 72419, 210921, 2165, 236781, 236929, 26595, 2165, 236762, 236929, 54005, 237873, 209458, 236900, 42888, 44068, 2165, 236781, 900, 570, 236929, 236900, 237921, 185992, 27654, 236924, 236743, 42991, 236900, 237408, 35134, 237105, 17161, 238780, 237522, 237967, 44068, 237410, 237380, 165220, 107, 1604, 107, 236775, 173229, 237184, 89045, 107, 236775, 238780, 237522, 70464, 134408, 119406, 236900, 116256, 5157, 38313, 18303, 209458, 237221, 62588, 19612, 238953, 185992, 19966, 27654, 236924, 138, 162576, 40923, 237078, 195780, 237221, 185992, 19612, 239301, 47972, 237702, 240307, 5938, 237479, 5157, 28639, 27654, 165220, 107, 236842, 107, 236783], 'total_duration': 334177220900, 'load_duration': 32704558900, 'prompt_eval_count': 21, 'prompt_eval_duration': 35097915900, 'eval_count': 256, 'eval_duration': 257750966600}
# {
# "解釋：":[
# "Python的函式就像是程式碼的指令，它們可以做各種事情。就像你教一個孩子做事情，函式就是給他們教的步驟。"
# ],
# "簡單來說：":[
# "函式是程式碼的組件，它們會執行特定的任務。 你可以把函式看作是程式碼的「步驟」，它們會根據你給的指示來做事情。 就像玩遊戲一樣，你給了指令，程式碼執行了那條路徑，就完成了遊戲。"
# ],
# "例子：":[
# "假設你想要計算一個數字，你可以寫一個函式：`def add(x, y):`  這表示，這個函式叫做 `add`，它接受兩個數字 `x` 和 `y` 作為參數，然後計算 `x + y`，再輸出結果。 這樣，你就可以用這個函式來計算加法。"
# ],
# "重點：":[
# "函式必須有一個名稱，並且可以接受一些參數（輸入），並輸出一個結果。  它們也可以有返回值（輸出），讓程式後續使用時可以得到結果。"
# ]
# }

# %%
import requests

def chat_with_ollama(prompt: str):
    url = "http://localhost:11434/api/generate"
    payload = {
        "model": "gemma3:270m",
        "prompt": prompt,
        "stream": False,
        # 移除 format: "json" 參數，讓模型正常回應
        "options": {
            "temperature": 0.7,
            "top_p": 0.9,
            "top_k": 50,
        }
    }

    response = requests.post(url, json=payload)
    result = response.json()
    print("💬 AI 回應：")
    print(result)
    
    if "response" in result:
        print(f"\n📝 回答內容：\n{result['response']}")
    else:
        print("❌ 沒有找到回應內容")
        print("可用的欄位:", list(result.keys()))

#範例輸入
chat_with_ollama("請用簡單的方式解釋什麼是Python的函式？")
# Out:
# 💬 AI 回應：
# {'model': 'gemma3:270m', 'created_at': '2025-09-15T03:12:09.3251768Z', 'response': '好的，用簡單的方式解釋Python的函式：\n\n**Python函式就像一個非常簡單的「指令」：**\n\n*   **「指令」：** 函式是為了執行特定任務，例如：\n    *   **輸入：** 接收輸入值，例如：`print("Hello, world!")`\n    *   **輸出：** 將輸入值輸出給螢幕，例如：`print("Hello, world!")`\n    *   **處理：** 處理輸入的結果，例如：`if x > 5: print("x is greater than 5")`\n    *   **控制：** 控制程序的執行流程，例如：`import random; print(random.randint(1, 10))`\n\n*   **「指令」：** 函式通常包含一些簡單的「指令」，例如：\n    *   **參數：** 讓函式接收的參數，例如：`my_variable = 10`\n    *   **返回值：** 根據參數的值，將結果傳給使用者。\n    *   **控制：** 讓函式控制程序的執行流程，例如：`if my_variable > 5: print("my_variable is greater than 5")`\n\n**總結來說，函式就像一個簡單的「程式碼」，用於執行特定任務，並根據輸入值提供輸出。**\n\n**例子：**\n\n假設你想要在控制台寫一段程式碼，你可以使用 Python 的函式來執行這個程式碼。\n\n*   **輸入：** 你輸入一個數字，例如：`my_number = 10`\n*   **輸出：** 程式碼會打印 "Hello, world!"\n*   **處理：** 程式碼會根據輸入的值，並將結果傳給螢幕。\n\n**總結：**\n\nPython函式就像一個簡單的「程式碼」，用於執行特定任務，並根據輸入值提供輸出。\n\n希望這個解釋對你有所幫助！', 'done': True, 'done_reason': 'stop', 'context': [105, 2364, 107, 239230, 237105, 74624, 48280, 185411, 26549, 237026, 32651, 236918, 238780, 237522, 237536, 106, 107, 105, 4368, 107, 18518, 236900, 237105, 74624, 48280, 185411, 32651, 236918, 238780, 237522, 237184, 107, 107, 1018, 32651, 238780, 237522, 55326, 19966, 13869, 74624, 236918, 237374, 81582, 237377, 237184, 1018, 107, 107, 236829, 138, 5213, 237374, 81582, 237377, 237184, 1018, 236743, 238780, 237522, 237026, 73912, 78204, 60009, 152807, 236900, 34313, 237184, 107, 138, 138, 236829, 138, 5213, 62588, 237184, 1018, 236743, 70667, 62588, 237987, 236900, 34313, 237184, 236929, 1995, 885, 9259, 236764, 1902, 26577, 236929, 107, 138, 138, 236829, 138, 5213, 185992, 237184, 1018, 212920, 62588, 237987, 185992, 238966, 243788, 239510, 236900, 34313, 237184, 236929, 1995, 885, 9259, 236764, 1902, 26577, 236929, 107, 138, 138, 236829, 138, 5213, 93521, 237184, 1018, 236743, 93521, 62588, 236918, 27654, 236900, 34313, 237184, 236929, 584, 1123, 1890, 236743, 236810, 236787, 1887, 885, 236781, 563, 5314, 1082, 236743, 236810, 1373, 236929, 107, 138, 138, 236829, 138, 5213, 21826, 237184, 1018, 153628, 175415, 78204, 56946, 236900, 34313, 237184, 236929, 1106, 4940, 236793, 1887, 236769, 7513, 236761, 33156, 236769, 236770, 236764, 236743, 236770, 236771, 225347, 107, 107, 236829, 138, 5213, 237374, 81582, 237377, 237184, 1018, 236743, 238780, 237522, 30346, 37250, 18303, 74624, 236918, 237374, 81582, 48311, 34313, 237184, 107, 138, 138, 236829, 138, 5213, 209458, 237184, 1018, 236743, 239301, 238780, 237522, 70667, 236918, 209458, 236900, 34313, 237184, 236929, 3307, 236779, 22785, 578, 236743, 236770, 236771, 236929, 107, 138, 138, 236829, 138, 5213, 195780, 237184, 1018, 236743, 99647, 209458, 73797, 236900, 239079, 27654, 239878, 238966, 148632, 236924, 107, 138, 138, 236829, 138, 5213, 21826, 237184, 1018, 236743, 239301, 238780, 237522, 21826, 175415, 78204, 56946, 236900, 34313, 237184, 236929, 584, 1041, 236779, 22785, 1890, 236743, 236810, 236787, 1887, 885, 3307, 236779, 22785, 563, 5314, 1082, 236743, 236810, 1373, 236929, 107, 107, 1018, 240018, 238331, 94757, 236900, 238780, 237522, 55326, 19966, 74624, 236918, 237374, 47972, 240897, 48311, 190843, 78204, 60009, 152807, 236900, 238953, 99647, 62588, 237987, 12680, 185992, 236924, 1018, 107, 107, 1018, 69954, 237184, 1018, 107, 107, 206402, 237408, 34860, 237075, 21826, 237838, 240564, 71553, 47972, 240897, 236900, 71407, 5938, 17856, 10363, 238780, 237522, 237967, 78204, 17161, 47972, 240897, 236924, 107, 107, 236829, 138, 5213, 62588, 237184, 1018, 43758, 62588, 19966, 210921, 236900, 34313, 237184, 236929, 3307, 236779, 5640, 578, 236743, 236770, 236771, 236929, 107, 236829, 138, 5213, 185992, 237184, 1018, 236743, 47972, 240897, 238003, 69718, 623, 9259, 236764, 1902, 9332, 107, 236829, 138, 5213, 93521, 237184, 1018, 236743, 47972, 240897, 238003, 99647, 62588, 73797, 236900, 238953, 239079, 27654, 239878, 238966, 243788, 239510, 236924, 107, 107, 1018, 240018, 238331, 237184, 1018, 107, 107, 32651, 2 ...
#
# 📝 回答內容：
# 好的，用簡單的方式解釋Python的函式：
#
# **Python函式就像一個非常簡單的「指令」：**
#
# *   **「指令」：** 函式是為了執行特定任務，例如：
#     *   **輸入：** 接收輸入值，例如：`print("Hello, world!")`
#     *   **輸出：** 將輸入值輸出給螢幕，例如：`print("Hello, world!")`
#     *   **處理：** 處理輸入的結果，例如：`if x > 5: print("x is greater than 5")`
#     *   **控制：** 控制程序的執行流程，例如：`import random; print(random.randint(1, 10))`
#
# *   **「指令」：** 函式通常包含一些簡單的「指令」，例如：
#     *   **參數：** 讓函式接收的參數，例如：`my_variable = 10`
#     *   **返回值：** 根據參數的值，將結果傳給使用者。
#     *   **控制：** 讓函式控制程序的執行流程，例如：`if my_variable > 5: print("my_variable is greater than 5")`
#
# **總結來說，函式就像一個簡單的「程式碼」，用於執行特定任務，並根據輸入值提供輸出。**
#
# **例子：**
#
# 假設你想要在控制台寫一段程式碼，你可以使用 Python 的函式來執行這個程式碼。
#
# *   **輸入：** 你輸入一個數字，例如：`my_number = 10`
# *   **輸出：** 程式碼會打印 "Hello, world!"
# *   **處理：** 程式碼會根據輸入的值，並將結果傳給螢幕。
#
# **總結：**
#
# Python函式就像一個簡單的「程式碼」，用於執行特定任務，並根據輸入值提供輸出。
#
# 希望這個解釋對你有所幫助！
